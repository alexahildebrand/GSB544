# %%
from plotnine import ggplot, aes, geom_point, labs, theme_classic, lims, geom_text, scale_color_manual, scale_fill_manual, scale_y_continuous, scale_x_continuous
from plotnine import scale_x_log10, theme_gray, element_text, theme, element_line, theme_light, scale_size, scale_size_area

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Question 1

# %% [markdown]
# #Identify, and list here, what aesthetics are being used and which variables are being mapped to each aesthetic.
#
# The x variable is income and y variable is life expectancy. The fill is world regions which determines the color. The size is based on population.

# %%
#Import the q1data.csv dataset.
df1 = pd.read_csv('C:/Users/alexa/OneDrive/Desktop/GSB544/data/q1data.csv')

# %%
df1
# Out:
#       income  life_exp  population  year      country four_regions  \
# 0     1910.0      61.0  29200000.0  2010  Afghanistan         asia
# 1    11100.0      78.1   2950000.0  2010      Albania       europe
# 2    11100.0      74.7  36000000.0  2010      Algeria       africa
# 3    46900.0      81.9     84500.0  2010      Andorra       europe
# 4     7680.0      60.8  23400000.0  2010       Angola       africa
# ..       ...       ...         ...   ...          ...          ...
# 192  20400.0      75.4  28400000.0  2010    Venezuela     americas
# 193   5350.0      73.3  88000000.0  2010      Vietnam         asia
# 194   4700.0      67.8  23200000.0  2010        Yemen         asia
# 195   3200.0      57.5  13600000.0  2010       Zambia       africa
# 196   2560.0      54.4  12700000.0  2010     Zimbabwe       africa
#
#                   six_regions       eight_regions           world_bank_region
# 0                  south_asia           asia_west                  South Asia
# ...

# %%
#Recreate the plot as best you can using plotnine.

#income elevel 1, 2, 3, 4 on top
#per person gdp capita bottom
#do I need x scale to be 16k, 32k, 64k
#2010 went away
#add years to life expectancy
#dots are super small
#take out nan?
#missing rows issue?
#too many lines in background

color_dict = {'africa':'cyan',
             'americas':'lime',
             'europe':'yellow',
             'asia':'deeppink'}

population_values = [1000000,250000000,500000000,750000000,1000000000]

(
ggplot(df1,aes(x="income", y="life_exp", fill = "four_regions"))
+scale_y_continuous(breaks = np.arange(0,91,10), limits = [20,90])
+scale_x_log10(breaks =[500,1000,2000,4000,8000,16000,32000,64000])
+geom_text (aes(label = '2010'), color = "lightgray", x=8000,y=60, ha='center', va='center', size = 30)
#+geom_text (aes(label = 'per person'), color = "lightgray", x=60000,y=10,ha='center', va='center',size = 40)
+geom_point(aes(size='population'))
#+scale_size (range =(3,10))
+scale_size_area(breaks =population_values)
+theme_light()
#+theme(text = element_text(color="dimgray"),
     # axis_line_x =element_line(color = "darkgray"),
     # axis_line_y =element_line(color = "darkgray"),
      #line = element_line(color="lightgray", size =1.4))
+scale_color_manual(values = color_dict)
+scale_fill_manual(values = color_dict)
+labs(y = "Life Expectancy", x="Income")
+labs(fill = "World Regions")
+labs(size = "Population")    
)
# Out:
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\layer.py:364: PlotnineWarning: geom_point : Removed 4 rows containing missing values.
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\guides\guides.py:197: PlotnineWarning: Cannot generate legend for the 'color' aesthetic. Make sure you have mapped a variable to it
# <Figure Size: (640 x 480)>

# %% [markdown]
# #What other geometries could you use here besides geom_point? Provide an actual plot of another geometry being used here and why it’s good or bad for visualizing these data.

# %% [markdown]
# References: https://plotnine.readthedocs.io/en/stable/api.html
# https://dputhier.github.io/jgb53d-bd-prog_github/practicals/intro_ggplot/intro_ggplot.html
# https://t-redactyl.io/blog/2020/09/making-beautiful-boxplots-using-plotnine-in-python.html
# https://www.datanovia.com/en/blog/ggplot-log-scale-transformation/

# %% [markdown]
# # Question 2

# %% [markdown]
# #Identify, and list here, what aesthetics are being used and which variables are being mapped to each aesthetic.
#
# The x variable is exports as a % of GDP and y variable is Imports as a % of GDP The fill is world regions which determines the color. The size is based on Energy use.

# %%
#Import the q2data.csv dataset.
df2 = pd.read_csv('C:/Users/alexa/OneDrive/Desktop/GSB544/data/q2data.csv')

# %%
df2
# Out:
#      imports  exports energy  year                country four_regions  \
# 0        NaN      NaN    NaN  1997            Afghanistan         asia
# 1       36.7     11.5    427  1997                Albania       europe
# 2       22.5     22.6    825  1997                Algeria       africa
# 3        NaN      NaN    NaN  1997         American Samoa          NaN
# 4        NaN      NaN    434  1997                 Angola       africa
# ..       ...      ...    ...   ...                    ...          ...
# 201     52.2     44.8    340  1997                Vietnam         asia
# 202      NaN      NaN    NaN  1997  Virgin Islands (U.S.)          NaN
# 203      NaN      NaN    241  1997                  Yemen          NaN
# 204     31.6     24.6    617  1997                 Zambia       africa
# 205     45.1     43.4    845  1997               Zimbabwe       africa
#
#                   six_regions       eight_regions           world_bank_region
# ...

# %%
#recreate plot as best you can using plotnine

# %%
# if there is a k, then regex to 1000
df2['energy'] = pd.to_numeric(df2['energy'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "12.4k"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-d9c2f6d0575c> in <module>
# ----> 1 df2['energy'] = pd.to_numeric(df2['energy'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast, dtype_backend)
#     215         coerce_numeric = errors not in ("ignore", "raise")
#     216         try:
# --> 217             values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218                 values,
#     219                 set(),
#
# ...

# %%
energy_values = [1100,1500, 1700,2500,3500,4500,8000,10000]
(
ggplot(df2,aes(x="exports", y="imports", fill = "four_regions"))
+scale_y_continuous(breaks = np.arange(0,401,50), limits = [50,400])
+scale_x_continuous(breaks =np.arange(0,221,20), limits = [20,220])
+geom_text (aes(label = '1997'), color = "lightgray", x=140,y=200, ha='center', va='center', size = 30)
+geom_point(aes(size='energy'))
#+scale_size (range =(3,10))
+scale_size_area(breaks =energy_values)
+theme_light()
#+theme(text = element_text(color="dimgray"),
     # axis_line_x =element_line(color = "darkgray"),
     # axis_line_y =element_line(color = "darkgray"),
      #line = element_line(color="lightgray", size =1.4))
+scale_color_manual(values = color_dict)
+scale_fill_manual(values = color_dict)
+labs(y = "Imports(\% of GDP)", x="Exports(\% of GDP)")
+labs(fill = "World Regions")
+labs(size = "Energy Use")    
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %% [markdown]
# # Question 3

# %% [markdown]
# #Identify, and list here, what aesthetics are being used and which variables are being mapped to each aesthetic.
#
# The x variable is internet users and y variable is GDP per capita. The fill is world regions which determines the color. The size is based on Income.

# %%
#Import the q3data.csv dataset.
df3 = pd.read_csv('C:/Users/alexa/OneDrive/Desktop/GSB544/data/q3data.csv')

# %%
df3
# Out:
#      internet_users      gdp   income  year                country  \
# 0           0.00456    330.0   1190.0  2001            Afghanistan
# 1           0.39000   2570.0   6780.0  2001                Albania
# 2           1.59000   3770.0   9230.0  2001                Algeria
# 3               NaN  10500.0      NaN  2001         American Samoa
# 4          11.30000  42600.0  35600.0  2001                Andorra
# ..              ...      ...      ...   ...                    ...
# 210         1.85000    847.0   3270.0  2001                Vietnam
# 211        27.50000  36700.0      NaN  2001  Virgin Islands (U.S.)
# 212         0.51900   1190.0   4940.0  2001                  Yemen
# 213         0.47800    991.0   2080.0  2001                 Zambia
# 214         1.10000   1330.0   3190.0  2001               Zimbabwe
#
#     four_regions               six_regions       eight_regions  \
# 0           asia                south_asia           asia_west
# ...

# %%
#is gdp already in gdp per capita
#how to do y scale

(
ggplot(df3,aes(x="internet_users", y="gdp", fill = "four_regions"))
#+scale_y_continuous(breaks = np.arange(0,401,50), limits = [50,400])
+scale_x_continuous(breaks =np.arange(0,91,10), limits = [10,90])
+geom_text (aes(label = '2001'), color = "lightgray", x=50,y=5000, ha='center', va='center', size = 30)
+geom_point(aes(size='income'))
#+scale_size (range =(3,10))
#+scale_size_area(breaks =energy_values)
+theme_light()
#+theme(text = element_text(color="dimgray"),
     # axis_line_x =element_line(color = "darkgray"),
     # axis_line_y =element_line(color = "darkgray"),
      #line = element_line(color="lightgray", size =1.4))
+scale_color_manual(values = color_dict)
+scale_fill_manual(values = color_dict)
+labs(y = "GDP/capita", x="Individuals using the Internet")
+labs(fill = "World Regions")
+labs(size = "Income")    
)
# Out:
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\layer.py:364: PlotnineWarning: geom_point : Removed 215 rows containing missing values.
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\guides\guides.py:197: PlotnineWarning: Cannot generate legend for the 'color' aesthetic. Make sure you have mapped a variable to it
# <Figure Size: (640 x 480)>
