# %% [raw]
# ---
# self-contained: true
# title: "Lab 1"
# format:
#     html:
#         theme: cerulean
# author: "Alexa Hildebrand"
# ---

# %%
from plotnine import ggplot, aes, geom_point, labs, theme_classic, lims, geom_text, scale_color_manual, scale_fill_manual, scale_y_continuous, scale_x_continuous, scale_y_log10
from plotnine import scale_x_log10, theme_gray, element_text, theme, element_line, theme_light, scale_size, scale_size_area, annotate, geom_boxplot, facet_wrap, geom_violin

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Task 1

# %% [markdown]
# ## Part 1: Identify, and list here, what aesthetics are being used and which variables are being mapped to each aesthetic.
#
# The x variable is income and y variable is life_exp which is life expectancy. The fill is four_regions which is the 4 world regions used to determine the color. The size is based on population.

# %% [markdown]
# ## Part 2: Import q1data.csv dataset

# %%
#Import the q1data.csv dataset.
df1 = pd.read_csv('C:/Users/alexa/OneDrive/Desktop/GSB544/data/q1data.csv')

# %%
df1
# Out:
#       income  life_exp  population  year      country four_regions  \
# 0     1910.0      61.0  29200000.0  2010  Afghanistan         asia
# 1    11100.0      78.1   2950000.0  2010      Albania       europe
# 2    11100.0      74.7  36000000.0  2010      Algeria       africa
# 3    46900.0      81.9     84500.0  2010      Andorra       europe
# 4     7680.0      60.8  23400000.0  2010       Angola       africa
# ..       ...       ...         ...   ...          ...          ...
# 192  20400.0      75.4  28400000.0  2010    Venezuela     americas
# 193   5350.0      73.3  88000000.0  2010      Vietnam         asia
# 194   4700.0      67.8  23200000.0  2010        Yemen         asia
# 195   3200.0      57.5  13600000.0  2010       Zambia       africa
# 196   2560.0      54.4  12700000.0  2010     Zimbabwe       africa
#
#                   six_regions       eight_regions           world_bank_region
# 0                  south_asia           asia_west                  South Asia
# ...

# %%
#remove misssing values
df1 = df1.dropna()

# %% [markdown]
# ## Part 3: Recreate the plot as best you can using plotnine

# %%
color_dict = {'africa':'cyan',
             'americas':'lime',
             'europe':'yellow',
             'asia':'#FF0078' }

population_values = [10000000,250000000,500000000,750000000,1000000000]

(
ggplot(df1,aes(x="income", y="life_exp", fill = "four_regions"))
+annotate ("text", label = "2010", x=6000,y=50, color = "lightgray", size = 175)
+geom_point(aes(size='population'))
+scale_x_log10(breaks = [500,1000,2000,4000,8000,16000,32000,64000],labels =[500,1000,2000,4000,8000,'16k', '32k', '64k'], limits = (0,120000))
+scale_size_area(max_size = 25,breaks =population_values)
+annotate ("text", label = "per person(GDP/capita, PPPS inflation-adjusted)", x=51000,y=15, color = "gray", size = 6)
+annotate ("text", label = "years", x=300,y=89, color = "gray", size = 7, angle =90)
+annotate ("text", label = "INCOME LEVEL 1", x=1200,y=90, color = "gray", size = 9)
+annotate ("text", label = "◆", x=2500,y=90, color = "gray", size = 9)   
+annotate ("text", label = "LEVEL 2", x=4400,y=90, color = "gray", size = 9)
+annotate ("text", label = "◆", x=8000,y=90, color = "gray", size = 9)   
+annotate ("text", label = "LEVEL 3", x=14000,y=90, color = "gray", size = 9)
+annotate ("text", label = "◆", x=23000,y=90, color = "gray", size = 9)   
+annotate ("text", label = "LEVEL 4", x=45000,y=90, color = "gray", size = 9)
+scale_y_continuous(breaks = [20,30,40,50,60,70,80,90], limits = [15,90])
+theme_light()
+scale_color_manual(values = color_dict)
+scale_fill_manual(values = color_dict)
+labs(y = "Life Expectancy", x="Income")
+labs(fill = "World Regions")
+labs(size = "Population")
+theme(figure_size = (10,6))
)
# Out:
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\scales\scale.py:783: RuntimeWarning: divide by zero encountered in log10
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\guides\guides.py:197: PlotnineWarning: Cannot generate legend for the 'color' aesthetic. Make sure you have mapped a variable to it
# <Figure Size: (1000 x 600)>

# %% [markdown]
# ## Part 4: What other geometries could you use here besides geom_point? Provide an actual plot of another geometry being used here and why it’s good or bad for visualizing these data.

# %%
(
ggplot(df1,aes(x="income", y="life_exp", fill = "four_regions"))
+scale_y_continuous(breaks = np.arange(0,91,10), limits = [20,90])
+scale_x_log10(breaks = [500,1000,2000,4000,8000,16000,32000,64000],labels =[500,1000,2000,4000,8000,'16k', '32k', '64k'], limits = (500,120000))
+geom_violin(aes(size='population'))
+scale_size_area(breaks =population_values)
+theme_light()
+scale_color_manual(values = color_dict)
+scale_fill_manual(values = color_dict)
+labs(y = "Life Expectancy", x="Income")
+labs(fill = "World Regions")
+labs(size = "Population")    
)
# Out:
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\positions\position.py:229: PlotnineWarning: position_dodge requires non-overlapping x intervals
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\guides\guides.py:197: PlotnineWarning: Cannot generate legend for the 'color' aesthetic. Make sure you have mapped a variable to it
# <Figure Size: (640 x 480)>

# %% [markdown]
# The aesthetics here include the x variable of income, y variable of life_exp. Fill of four_regions which determines the color and size is based on population.
#
# This is another way to represent the data, however it provides much less information than the previous bubble plot since it is summarizing the individual points. It takes away the meaning of specific values which makes it less effective to understand what is going on in this plot. Much more meaningful insights could be derived from the bubbleplot. Violin plots are helpful at understanding medians, ranges of values, and size of distribution.

# %% [markdown]
# References: https://plotnine.readthedocs.io/en/stable/api.html;
# https://dputhier.github.io/jgb53d-bd-prog_github/practicals/intro_ggplot/intro_ggplot.html;
# https://t-redactyl.io/blog/2020/09/making-beautiful-boxplots-using-plotnine-in-python.html;
# https://www.datanovia.com/en/blog/ggplot-log-scale-transformation/;
# https://www.geeksforgeeks.org/drop-rows-from-pandas-dataframe-with-missing-values-or-nan-in-columns/

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Part 1: Identify, and list here, what aesthetics are being used and which variables are being mapped to each aesthetic.
#
# The x variable is exports as a % of GDP and y variable is imports as a % of GDP. The fill is four_regions which is world regions used to determine the color. The size is based on energy which is the energy usage.

# %% [markdown]
# ## Part 2: Import the q2data.csv dataset

# %%
#Import the q2data.csv dataset.
df2 = pd.read_csv('C:/Users/alexa/OneDrive/Desktop/GSB544/data/q2data.csv')

# %%
df2
# Out:
#      imports  exports energy  year                country four_regions  \
# 0        NaN      NaN    NaN  1997            Afghanistan         asia
# 1       36.7     11.5    427  1997                Albania       europe
# 2       22.5     22.6    825  1997                Algeria       africa
# 3        NaN      NaN    NaN  1997         American Samoa          NaN
# 4        NaN      NaN    434  1997                 Angola       africa
# ..       ...      ...    ...   ...                    ...          ...
# 201     52.2     44.8    340  1997                Vietnam         asia
# 202      NaN      NaN    NaN  1997  Virgin Islands (U.S.)          NaN
# 203      NaN      NaN    241  1997                  Yemen          NaN
# 204     31.6     24.6    617  1997                 Zambia       africa
# 205     45.1     43.4    845  1997               Zimbabwe       africa
#
#                   six_regions       eight_regions           world_bank_region
# ...

# %% [markdown]
# ## Part 3: Recreate the plot as best you can using plotnine

# %%
#remove missing values
df2 = df2.dropna()
df2
# Out:
#      imports  exports energy  year     country four_regions  \
# 1       36.7     11.5    427  1997     Albania       europe
# 2       22.5     22.6    825  1997     Algeria       africa
# 6       12.9     10.4   1660  1997   Argentina     americas
# 7       52.8     19.0    610  1997     Armenia       europe
# 9       20.5     19.6   5550  1997   Australia         asia
# ..       ...      ...    ...   ...         ...          ...
# 198     22.9     22.6   2080  1997  Uzbekistan         asia
# 200     22.7     20.9   2250  1997   Venezuela     americas
# 201     52.2     44.8    340  1997     Vietnam         asia
# 204     31.6     24.6    617  1997      Zambia       africa
# 205     45.1     43.4    845  1997    Zimbabwe       africa
#
#                   six_regions       eight_regions           world_bank_region
# 1         europe_central_asia         europe_east       Europe & Central Asia
# 2    middle_east_north_africa        africa_north  Middle East & North Africa
# ...

# %%
#understand why the error regarding non numeric values was occuring
df2['energy']
contains_k=df2['energy'].str.contains('k')
df2[contains_k]
# Out:
#      imports  exports energy  year  country four_regions  \
# 13      63.9     64.6  12.4k  1997  Bahrain         asia
# 151     40.0     51.1  19.3k  1997    Qatar         asia
#
#                   six_regions eight_regions           world_bank_region  \
# 13   middle_east_north_africa     asia_west  Middle East & North Africa
# 151  middle_east_north_africa     asia_west  Middle East & North Africa
#
#     energy_use
# 13       12400
# 151      19300

# %%
df2['energy'] = df2['energy'].astype(str)
energy_use = []

#replace those with 12.4k to 12400
for x in df2['energy']:
    if re.finditer('k', x):
        x = x.replace("k", "00")
        x = x.replace(".", "")
        energy_use.append(x)
    else:
        energy_use.append(x)  

df2['energy_use'] = energy_use

df2['energy_use'] = df2['energy_use'].astype(float)

# %%
df2['energy_use']
# Out:
# 1       427.0
# 2       825.0
# 6      1660.0
# 7       610.0
# 9      5550.0
#         ...
# 198    2080.0
# 200    2250.0
# 201     340.0
# 204     617.0
# 205     845.0
# Name: energy_use, Length: 127, dtype: float64

# %%
energy_values = [500,1100,1500, 1700,2500,3500,4500,8000,10000, 50000]
(
ggplot(df2,aes(x="exports", y="imports", fill = "four_regions"))
+scale_y_continuous(breaks = [50,100,150,200,250,300,350,400], limits = [0,450])
+scale_x_continuous(breaks = [20,40,60,80,100,120,140,160,180,200,220], limits = [0,240])
+geom_text (aes(label = '1997'), color = "lightgray", x=120,y=220, ha='center', va='center', size = 200)
+geom_point(aes(size='energy_use'))
+scale_size_area(max_size = 20, breaks =energy_values)
+theme_light()
+scale_color_manual(values = color_dict)
+scale_fill_manual(values = color_dict)
+labs(y = "Imports(\% of GDP)", x="Exports(\% of GDP)")
+labs(fill = "World Regions")
+labs(size = "Energy Use")    
+theme(figure_size = (10,6), axis_text_y=element_text(rotation=90))
)
# Out:
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\guides\guides.py:197: PlotnineWarning: Cannot generate legend for the 'color' aesthetic. Make sure you have mapped a variable to it
# <Figure Size: (1000 x 600)>

# %% [markdown]
# References: https://www.w3schools.com/python/ref_string_replace.asp; https://stackoverflow.com/questions/47714540/plotnine-rotating-labels

# %% [markdown]
# ## Part 4: What other geometries could you use here besides geom_point? Provide an actual plot of another geometry being used here and why it’s good or bad for visualizing these data.

# %%
plot1 = (
ggplot(df2,aes(x="four_regions", y="imports", fill = "four_regions"))
+scale_y_continuous(breaks = [25,50,75,100,125, 150], limits = [0,150])
+geom_violin()
+theme_light()
+scale_color_manual(values = color_dict)
+scale_fill_manual(values = color_dict)
+labs(y = "Imports(\% of GDP)", x="World Region")
+labs(fill = "World Regions")
)

plot2= (
ggplot(df2,aes(x="four_regions", y="energy_use", fill = "four_regions"))
+scale_y_log10(breaks = [200,500,1000,2000,5000,10000,20000,50000], limits = [100,55000], labels = [200,500,100,2000,5000,'10k', '20k', '50k'])
+geom_violin()
+theme_light()
+scale_color_manual(values = color_dict)
+scale_fill_manual(values = color_dict)
+labs(y = "Energy Use", x="World Region")
+labs(fill = "World Regions")
)

plot3 =(
ggplot(df2,aes(x="four_regions", y="exports", fill = "four_regions"))
+geom_violin()
+theme_light()
+scale_color_manual(values = color_dict)
+scale_fill_manual(values = color_dict)
+labs(x="World Region", y = "Exports(\% of GDP)")
+labs(fill = "World Regions")
)

print(plot1)
print(plot2)
print(plot3)
# Out:
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\guides\guides.py:197: PlotnineWarning: Cannot generate legend for the 'color' aesthetic. Make sure you have mapped a variable to it
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\guides\guides.py:197: PlotnineWarning: Cannot generate legend for the 'color' aesthetic. Make sure you have mapped a variable to it
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\guides\guides.py:197: PlotnineWarning: Cannot generate legend for the 'color' aesthetic. Make sure you have mapped a variable to it

# %% [markdown]
# Here there are 3 seperate graphs, this is similar to facetting however it is using a different y numeric variable for each. Plot 1 has x variable four_region and y variable imports and the fill is determined by four_region as well. Plot 2 has x variable four_region and y variable energy and fill is four_region. Lastly, plot 3 has x variable four_region, y variable exports, and fill four_region.
#
# This is worse to visualize the data because you need to look at three seperate plots while the bubble plot is able to show it all on one graph. The three violin plats are helpful at breaking down each numeric variable based on world region but not helpful in understanding them all together. Violin plots can also be slightly difficult to interpret but helpful at showing medians and ranges of values.

# %% [markdown]
# # Task 3

# %% [markdown]
# ## Part 1: Identify, and list here, what aesthetics are being used and which variables are being mapped to each aesthetic.
#
# The x variable is internet_users which is Individuals using the internet and y variable is gdp which is GDP per capita. The fill is four_regions which is the world region and it is used to determine the color. The size is based on income.

# %% [markdown]
# ## Part 2: Import q3data.csv dataset

# %%
#Import the q3data.csv dataset.
df3 = pd.read_csv('C:/Users/alexa/OneDrive/Desktop/GSB544/data/q3data.csv')

# %%
df3
# Out:
#      internet_users      gdp   income  year                country  \
# 0           0.00456    330.0   1190.0  2001            Afghanistan
# 1           0.39000   2570.0   6780.0  2001                Albania
# 2           1.59000   3770.0   9230.0  2001                Algeria
# 3               NaN  10500.0      NaN  2001         American Samoa
# 4          11.30000  42600.0  35600.0  2001                Andorra
# ..              ...      ...      ...   ...                    ...
# 210         1.85000    847.0   3270.0  2001                Vietnam
# 211        27.50000  36700.0      NaN  2001  Virgin Islands (U.S.)
# 212         0.51900   1190.0   4940.0  2001                  Yemen
# 213         0.47800    991.0   2080.0  2001                 Zambia
# 214         1.10000   1330.0   3190.0  2001               Zimbabwe
#
#     four_regions               six_regions       eight_regions  \
# 0           asia                south_asia           asia_west
# ...

# %%
#remove missing values
df3 = df3.dropna()
df3
# Out:
#      internet_users      gdp   income  year      country four_regions  \
# 0           0.00456    330.0   1190.0  2001  Afghanistan         asia
# 1           0.39000   2570.0   6780.0  2001      Albania       europe
# 2           1.59000   3770.0   9230.0  2001      Algeria       africa
# 4          11.30000  42600.0  35600.0  2001      Andorra       europe
# 5           0.27000   2440.0   2900.0  2001       Angola       africa
# ..              ...      ...      ...   ...          ...          ...
# 209         4.91000  10800.0  14800.0  2001    Venezuela     americas
# 210         1.85000    847.0   3270.0  2001      Vietnam         asia
# 212         0.51900   1190.0   4940.0  2001        Yemen         asia
# 213         0.47800    991.0   2080.0  2001       Zambia       africa
# 214         1.10000   1330.0   3190.0  2001     Zimbabwe       africa
#
#                   six_regions       eight_regions           world_bank_region
# ...

# %% [markdown]
# ## Part 3: Recreate the plot as best you can using plotnine

# %%
(
ggplot(df3,aes(x="internet_users", y="gdp", fill = "four_regions"))
+scale_y_log10(breaks = [200,500,1000,2000,5000,10000,20000,50000,100000],limits = [0,200000], labels = [200,500,1000,2000,5000,'10k','20k','50k', '100k'])
+scale_x_continuous(breaks =[10,20,30,40,50,60,70,80,90], limits = [0,100])
+annotate("text",label = '2001', color = "lightgray", x=50,y=5000, size = 150)
+annotate ("text", label ='\% of population', color = "gray", x=98,y=158, size = 7)
+annotate ("text", label = 'US$, inflation-adjusted', color = "gray", x=0,y=75000, size = 7, angle = 90)
+geom_point(aes(size='income'))
+scale_size_area(max_size = 15)
+theme_light()
+scale_color_manual(values = color_dict)
+scale_fill_manual(values = color_dict)
+labs(y = "GDP/capita", x="Individuals using the Internet")
+labs(fill = "World Regions")
+labs(size = "Income")    
+theme(figure_size = (10,6))
)
# Out:
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\scales\scale.py:783: RuntimeWarning: divide by zero encountered in log10
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\guides\guides.py:197: PlotnineWarning: Cannot generate legend for the 'color' aesthetic. Make sure you have mapped a variable to it
# <Figure Size: (1000 x 600)>

# %% [markdown]
# ## Part 4: What other geometries could you use here besides geom_point? Provide an actual plot of another geometry being used here and why it’s good or bad for visualizing these data.

# %%
plot_1 = (
ggplot(df3,aes(x="four_regions", y="gdp", fill = "four_regions"))
+scale_y_log10(breaks = [200,500,1000,2000,5000,10000,20000,50000,100000],limits = [0,200000], labels = [200,500,1000,2000,5000,'10k','20k','50k', '100k'])
+geom_boxplot()
+theme_light()
+scale_color_manual(values = color_dict)
+scale_fill_manual(values = color_dict)
+labs( x="World Regions", y = "GDP/capita" )
+labs(fill = "World Regions")  
)

plot_2 = (
ggplot(df3,aes(x="four_regions", y="income", fill = "four_regions"))
+geom_boxplot()
+theme_light()
+scale_color_manual(values = color_dict)
+scale_fill_manual(values = color_dict)
+labs( x="World Regions", y = "Income" )
+labs(fill = "World Regions")  
)

plot_3 = (
ggplot(df3,aes(x="four_regions", y="internet_users", fill = "four_regions"))
+geom_boxplot()
+theme_light()
+scale_color_manual(values = color_dict)
+scale_fill_manual(values = color_dict)
+labs( x="World Regions", y = "Individuals using the Internet" )
+labs(fill = "World Regions")  
)

print(plot_1)
print(plot_2)
print(plot_3)
# Out:
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\scales\scale.py:783: RuntimeWarning: divide by zero encountered in log10
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\guides\guides.py:197: PlotnineWarning: Cannot generate legend for the 'color' aesthetic. Make sure you have mapped a variable to it
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\guides\guides.py:197: PlotnineWarning: Cannot generate legend for the 'color' aesthetic. Make sure you have mapped a variable to it
# C:\Users\alexa\anaconda3\lib\site-packages\plotnine\guides\guides.py:197: PlotnineWarning: Cannot generate legend for the 'color' aesthetic. Make sure you have mapped a variable to it

# %% [markdown]
# The first plot has aesthetics of x is four_region, y is gdp, and fill is four_region. Plot 2 has x of four_region, y of income, and fill is four_region. The last plot has x as four_region, y as internet_users, and fill as four_region.
#
# The boxplots are helpful for understanding the median and quantiles of a numeric value against the categorical value. However, they require it to be on different plots so it is not as easy to understand how all four variables connect to each other. It is helpful to see the individual relationships between the numeric variable and world region. However, I don't think it is as helpful as seeing all of the variables on the same plot like the bubble plot created above.
